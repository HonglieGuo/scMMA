# %%
import anndata
import scanpy as sc
import sccross
import pandas as pd
from matplotlib import rcParams
from sklearn.metrics import adjusted_rand_score,normalized_mutual_info_score
import numpy as np
from sklearn.metrics import adjusted_rand_score as ari_score
from sklearn.metrics.cluster import normalized_mutual_info_score as nmi_score
from sklearn.metrics import calinski_harabasz_score, davies_bouldin_score, adjusted_mutual_info_score
from sklearn.metrics import fowlkes_mallows_score, homogeneity_score, completeness_score, v_measure_score, silhouette_score
from sklearn.cluster import KMeans
import timeit

start = timeit.default_timer()
# Out:
#  DeprecationWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/ignite/handlers/checkpoint.py:16: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.

# %%
def eva(y_true, y_pred):
    nmi = nmi_score(y_true, y_pred)
    ari = ari_score(y_true, y_pred)
    ami = adjusted_mutual_info_score(y_true, y_pred)
    fmi = fowlkes_mallows_score(y_true, y_pred)
    hom = homogeneity_score(y_true, y_pred)
    com = completeness_score(y_true, y_pred)
    v = v_measure_score(y_true, y_pred)
    return nmi, ari, ami, fmi, hom, com, v

def eva_nolabel(data, y):
    db = davies_bouldin_score(data, y)
    ch = calinski_harabasz_score(data, y)
    asw = silhouette_score(data, y)
    return db, ch, asw

# %%
rcParams["figure.figsize"] = (4, 4)
rna = anndata.read_h5ad("/data1/chengyue/gm/fig2/human_brain_3k/rna_preprocessed_n.h5ad")
atac = anndata.read_h5ad("/data1/chengyue/gm/fig2/human_brain_3k/atac_preprocessed_n.h5ad")
atac2rna = anndata.read_h5ad("/data1/chengyue/gm/fig2/human_brain_3k/atac2rna_n.h5ad")#5000
label_dir = '/data1/chengyue/gm/fig2/human_brain_3k/label.csv'
# Out:
#  UserWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/anndata/_core/anndata.py:1840: Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
atac.uns['gene'] = atac2rna

# label_dir = ""
rna.obs['domain'] = 'scRNA-seq'
atac.obs['domain'] = 'scATAC-seq'

sccross.models.configure_dataset(
    rna, "NB", use_highly_variable=True,
    use_layer = 'counts',
     use_rep="X_pca"
)

sccross.models.configure_dataset(
    atac, "NB", use_highly_variable=False,
    use_rep="X_lsi"
)
# = rna.obsm['X_pca'].iloc[:,-50:]
sccross.data.mnn_prior([rna,atac])
# Out:
#  TqdmWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/tqdm/auto.py:21: IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
#  SparseEfficiencyWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/scipy/sparse/_index.py:146: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
# GMT file c5.go.bp.v7.4.symbols.gmt loading ...
# 7481
# Number of genes in c5.go.bp.v7.4.symbols.gmt 16393
# GMT file c2.cp.v7.4.symbols.gmt loading ...
# 2922
# Number of genes in c2.cp.v7.4.symbols.gmt 12685
#  SparseEfficiencyWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/scipy/sparse/_index.py:146: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
# GMT file c5.go.bp.v7.4.symbols.gmt loading ...
# 7481
# Number of genes in c5.go.bp.v7.4.symbols.gmt 0
# GMT file c2.cp.v7.4.symbols.gmt loading ...
# 2922
# Number of genes in c2.cp.v7.4.symbols.gmt 0
#  RuntimeWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/sklearn/decomposition/_pca.py:640: invalid value encountered in divide
# View of AnnData object with n_obs × n_vars = 3233 × 19338
#     obs: 'barcodes', 'domain'
#     var: 'feature_id', 'feature_name', 'feature_type', 'chrom', 'chromStart', 'chromEnd', 'modality', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'hvg', 'log1p', 'neighbors', 'pca', 'umap', '__sccross__', 'gcn'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances', 'gcn_distances', 'gcn_connectivities' View of AnnData object with n_obs × n_vars = 3233 × 19338
#     obs: 'barcodes'
#     var: 'gene_type', 'tag', 'transcript_type', 'gene_name', 'hgnc_id', 'transcript_support_level', 'havana_transcript', 'transcript_id', 'level', 'gene_id', 'annotation', 'ont', 'protein_id', 'ccdsid', 'havana_gene', 'mean', 'std'
#     uns: 'log1p', 'neighbors', 'umap'
#     obsm: 'X_lsi', 'X_umap'
#     obsp: 'connectivities', 'distances'
#  NumbaDeprecationWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py:14: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#  NumbaWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py:14:
# Compilation is falling back to object mode WITH looplifting enabled because Function "l2_norm" failed type inference due to: No implementation of function Function(<function norm at 0x7f63b4bee9d0>) found for signature:
#
#  >>> norm(x=array(float32, 2d, A), axis=Literal[int](1))
#
# There are 2 candidate implementations:
#   - Of which 2 did not match due to:
#   Overload in function 'norm_impl': File: numba/np/linalg.py: Line 2427.
#     With argument(s): '(x=array(float32, 2d, A), axis=int64)':
#    Rejected as the implementation raised a specific error:
#      TypingError: got an unexpected keyword argument 'axis'
#   raised from /data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/numba/core/typing/templates.py:784
#
# During: resolving callee type: Function(<function norm at 0x7f63b4bee9d0>)
# During: typing of call at /data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py (16)
#
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 16:
# def l2_norm(in_matrix):
#     return np.linalg.norm(x=in_matrix, axis=1)
#     ^
#
#  NumbaWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/numba/core/object_mode_passes.py:151: Function "l2_norm" was compiled in object mode without forceobj=True.
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 15:
# @jit(float32[:](float32[:, :]), nogil=True)
# def l2_norm(in_matrix):
# ^
#
#  NumbaDeprecationWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/numba/core/object_mode_passes.py:161:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 15:
# @jit(float32[:](float32[:, :]), nogil=True)
# def l2_norm(in_matrix):
# ^
#
#  NumbaWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py:14: Code running in object mode won't allow parallel execution despite nogil=True.
#  NumbaDeprecationWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py:19: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#  NumbaDeprecationWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py:24: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#  NumbaPerformanceWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py:29: np.dot() is faster on contiguous arrays, called on (Array(float32, 1, 'A', False, aligned=True), Array(float32, 1, 'A', False, aligned=True))
#  NumbaDeprecationWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py:88: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#  NumbaWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py:88:
# Compilation is falling back to object mode WITH looplifting enabled because Function "find_mutual_nn" failed type inference due to: Untyped global name 'cKDTree': Cannot determine Numba type of <class 'type'>
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 90:
# def find_mutual_nn(data1, data2, k1, k2, n_jobs):
#     k_index_1 = cKDTree(data1).query(x=data2, k=k1, n_jobs=n_jobs)[1]
#     ^
#
#  NumbaWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py:88:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "find_mutual_nn" failed type inference due to: Untyped global name 'cKDTree': Cannot determine Numba type of <class 'type'>
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 90:
# def find_mutual_nn(data1, data2, k1, k2, n_jobs):
#     k_index_1 = cKDTree(data1).query(x=data2, k=k1, n_jobs=n_jobs)[1]
#     ^
#
#  NumbaWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/numba/core/object_mode_passes.py:151: Function "find_mutual_nn" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 88:
# def transform_input_data(datas, cos_norm_in, cos_norm_out, var_index, var_subset, n_jobs):
#     <source elided>
#
# @jit((float32[:, :], float32[:, :], int8, int8, int8))
# ^
#
#  NumbaDeprecationWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/numba/core/object_mode_passes.py:161:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 88:
# def transform_input_data(datas, cos_norm_in, cos_norm_out, var_index, var_subset, n_jobs):
#     <source elided>
#
# @jit((float32[:, :], float32[:, :], int8, int8, int8))
# ^
#
#  NumbaDeprecationWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py:102: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#  NumbaWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py:102:
# Compilation is falling back to object mode WITH looplifting enabled because Function "compute_correction" failed type inference due to: No implementation of function Function(<function unique at 0x7f63b4b1daf0>) found for signature:
#
#  >>> unique(array(int32, 1d, A), return_counts=Literal[bool](True))
#
# There are 2 candidate implementations:
#   - Of which 2 did not match due to:
#   Overload in function 'np_unique': File: numba/np/arrayobj.py: Line 2560.
#     With argument(s): '(array(int32, 1d, A), return_counts=bool)':
#    Rejected as the implementation raised a specific error:
#      TypingError: got an unexpected keyword argument 'return_counts'
#   raised from /data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/numba/core/typing/templates.py:784
#
# During: resolving callee type: Function(<function unique at 0x7f63b4b1daf0>)
# During: typing of call at /data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py (105)
#
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 105:
# def compute_correction(data1, data2, mnn1, mnn2, data2_or_raw2, sigma):
#     <source elided>
#     vect = data1[mnn1] - data2[mnn2]
#     mnn_index, mnn_count = np.unique(mnn2, return_counts=True)
#     ^
#
#  NumbaWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py:102:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "compute_correction" failed type inference due to: Cannot determine Numba type of <class 'numba.core.dispatcher.LiftedLoop'>
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 107:
# def compute_correction(data1, data2, mnn1, mnn2, data2_or_raw2, sigma):
#     <source elided>
#     vect_reduced = np.zeros((data2.shape[0], vect.shape[1]), dtype=np.float32)
#     for index, ve in zip(mnn2, vect):
#     ^
#
#  NumbaWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/numba/core/object_mode_passes.py:151: Function "compute_correction" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 102:
# def find_mutual_nn(data1, data2, k1, k2, n_jobs):
#     <source elided>
#
# @jit(float32[:, :](float32[:, :], float32[:, :], int32[:], int32[:], float32[:, :], float32))
# ^
#
#  NumbaDeprecationWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/numba/core/object_mode_passes.py:161:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 102:
# def find_mutual_nn(data1, data2, k1, k2, n_jobs):
#     <source elided>
#
# @jit(float32[:, :](float32[:, :], float32[:, :], int32[:], int32[:], float32[:, :], float32))
# ^
#
#  NumbaDeprecationWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py:199: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#  NumbaWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py:199:
# Compilation is falling back to object mode WITH looplifting enabled because Function "adjust_s_variance" failed type inference due to: NameError: name 'sq_dist_to_line' is not defined
#  NumbaWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py:199:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "adjust_s_variance" failed type inference due to: Cannot determine Numba type of <class 'numba.core.dispatcher.LiftedLoop'>
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 207:
# def adjust_s_variance(data1, data2, curcell, curvect, sigma):
#     <source elided>
#     totalprob2 = 0.
#     for samecell in data2:
#     ^
#
#  NumbaWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/numba/core/object_mode_passes.py:151: Function "adjust_s_variance" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 199:
# def adjust_shift_variance(data1, data2, correction, sigma, n_jobs, var_subset=None):
#     <source elided>
#
# @jit(float32(float32[:, :], float32[:, :], float32[:], float32[:], float32), nogil=True)
# ^
#
#  NumbaDeprecationWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/numba/core/object_mode_passes.py:161:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 199:
# def adjust_shift_variance(data1, data2, correction, sigma, n_jobs, var_subset=None):
#     <source elided>
#
# @jit(float32(float32[:, :], float32[:, :], float32[:], float32[:], float32), nogil=True)
# ^
#
#  NumbaWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py:199: Code running in object mode won't allow parallel execution despite nogil=True.
#  NumbaPerformanceWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py:238: np.dot() is faster on contiguous arrays, called on (Array(float32, 1, 'C', False, aligned=True), Array(float32, 1, 'A', False, aligned=True))
# Performing cosine normalization...
#  NumbaWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py:14:
# Compilation is falling back to object mode WITH looplifting enabled because Function "l2_norm" failed type inference due to: No implementation of function Function(<function norm at 0x7f63b4bee9d0>) found for signature:
#
#  >>> norm(x=array(float32, 2d, A), axis=Literal[int](1))
#
# There are 2 candidate implementations:
#     - Of which 2 did not match due to:
#     Overload in function 'norm_impl': File: numba/np/linalg.py: Line 2427.
#       With argument(s): '(x=array(float32, 2d, A), axis=int64)':
#      Rejected as the implementation raised a specific error:
#        TypingError: got an unexpected keyword argument 'axis'
#   raised from /data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/numba/core/typing/templates.py:784
#
# During: resolving callee type: Function(<function norm at 0x7f63b4bee9d0>)
# During: typing of call at /data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py (16)
#
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 16:
# def l2_norm(in_matrix):
#     return np.linalg.norm(x=in_matrix, axis=1)
#     ^
#
#  NumbaWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/numba/core/object_mode_passes.py:151: Function "l2_norm" was compiled in object mode without forceobj=True.
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 15:
# @jit(float32[:](float32[:, :]), nogil=True)
# def l2_norm(in_matrix):
# ^
#
#  NumbaDeprecationWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/numba/core/object_mode_passes.py:161:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 15:
# @jit(float32[:](float32[:, :]), nogil=True)
# def l2_norm(in_matrix):
# ^
#
#  NumbaWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py:14: Code running in object mode won't allow parallel execution despite nogil=True.
#  NumbaWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py:14:
# Compilation is falling back to object mode WITH looplifting enabled because Function "l2_norm" failed type inference due to: No implementation of function Function(<function norm at 0x7f63b4bee9d0>) found for signature:
#
#  >>> norm(x=array(float32, 2d, A), axis=Literal[int](1))
#
# There are 2 candidate implementations:
#     - Of which 2 did not match due to:
#     Overload in function 'norm_impl': File: numba/np/linalg.py: Line 2427.
#       With argument(s): '(x=array(float32, 2d, A), axis=int64)':
#      Rejected as the implementation raised a specific error:
#        TypingError: got an unexpected keyword argument 'axis'
#   raised from /data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/numba/core/typing/templates.py:784
#
# During: resolving callee type: Function(<function norm at 0x7f63b4bee9d0>)
# During: typing of call at /data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py (16)
#
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 16:
# def l2_norm(in_matrix):
#     return np.linalg.norm(x=in_matrix, axis=1)
#     ^
#
#  NumbaWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/numba/core/object_mode_passes.py:151: Function "l2_norm" was compiled in object mode without forceobj=True.
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 15:
# @jit(float32[:](float32[:, :]), nogil=True)
# def l2_norm(in_matrix):
# ^
#
#  NumbaDeprecationWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/numba/core/object_mode_passes.py:161:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 15:
# @jit(float32[:](float32[:, :]), nogil=True)
# def l2_norm(in_matrix):
# ^
#
#  NumbaWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py:14: Code running in object mode won't allow parallel execution despite nogil=True.
# Starting MNN correct iteration. Reference batch: 0
# Step 1 of 1: processing batch 1
#   Looking for MNNs...
#  NumbaWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py:88:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "find_mutual_nn" failed type inference due to: non-precise type pyobject
# During: typing of argument at /data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py (94)
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 94:
# def find_mutual_nn(data1, data2, k1, k2, n_jobs):
#     <source elided>
#     mutual_2 = []
#     for index_2 in range(data2.shape[0]):
#     ^
#
#  NumbaWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/numba/core/object_mode_passes.py:151: Function "find_mutual_nn" was compiled in object mode without forceobj=True.
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 94:
# def find_mutual_nn(data1, data2, k1, k2, n_jobs):
#     <source elided>
#     mutual_2 = []
#     for index_2 in range(data2.shape[0]):
#     ^
#
#  NumbaDeprecationWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/numba/core/object_mode_passes.py:161:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 94:
# def find_mutual_nn(data1, data2, k1, k2, n_jobs):
#     <source elided>
#     mutual_2 = []
#     for index_2 in range(data2.shape[0]):
#     ^
#   Computing correction vectors...
#  NumbaWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py:102:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "compute_correction" failed type inference due to: non-precise type pyobject
# During: typing of argument at /data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py (107)
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 107:
# def compute_correction(data1, data2, mnn1, mnn2, data2_or_raw2, sigma):
#     <source elided>
#     vect_reduced = np.zeros((data2.shape[0], vect.shape[1]), dtype=np.float32)
#     for index, ve in zip(mnn2, vect):
#     ^
#
#  NumbaWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/numba/core/object_mode_passes.py:151: Function "compute_correction" was compiled in object mode without forceobj=True.
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 107:
# def compute_correction(data1, data2, mnn1, mnn2, data2_or_raw2, sigma):
#     <source elided>
#     vect_reduced = np.zeros((data2.shape[0], vect.shape[1]), dtype=np.float32)
#     for index, ve in zip(mnn2, vect):
#     ^
#
#  NumbaDeprecationWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/numba/core/object_mode_passes.py:161:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/mnnpy/utils.py", line 107:
# def compute_correction(data1, data2, mnn1, mnn2, data2_or_raw2, sigma):
#     <source elided>
#     vect_reduced = np.zeros((data2.shape[0], vect.shape[1]), dtype=np.float32)
#     for index, ve in zip(mnn2, vect):
#     ^
#   Adjusting variance...
#   Applying correction...
# MNN correction complete. Gathering output...
# Packing AnnData object...
#  FutureWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/anndata/_core/anndata.py:1763: The AnnData.concatenate method is deprecated in favour of the anndata.concat function. Please use anndata.concat instead.
#
# See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
# Done.
# AnnData object with n_obs × n_vars = 6466 × 19338
#     obs: 'barcodes', 'domain', 'batch'
#     var: 'feature_id-0', 'feature_name-0', 'feature_type-0', 'chrom-0', 'chromStart-0', 'chromEnd-0', 'modality-0', 'highly_variable-0', 'highly_variable_rank-0', 'means-0', 'variances-0', 'variances_norm-0', 'mean-0', 'std-0', 'mean-1', 'std-1', 'gene_type-1', 'tag-1', 'transcript_type-1', 'gene_name-1', 'hgnc_id-1', 'transcript_support_level-1', 'havana_transcript-1', 'transcript_id-1', 'level-1', 'gene_id-1', 'annotation-1', 'ont-1', 'protein_id-1', 'ccdsid-1', 'havana_gene-1'
#     obsm: 'X_umap'

# %%
cross = sccross.models.fit_SCCROSS(
    {"rna": rna, "atac": atac}, 
    fit_kws={"directory": "sccross"}
)

rna.obsm["X_cross"] = cross.encode_data("rna", rna)
atac.obsm["X_cross"] = cross.encode_data("atac", atac)

combined = anndata.concat([rna, atac])
# Out:
# [INFO] fit_SCCROSS: Pretraining SCCROSS model...
# [INFO] autodevice: Using GPU 7 as computation device.
# {'directory': 'sccross/pretrain', 'align_burnin': inf, 'safe_burnin': False}
# {'shared_batches': False}
# [INFO] SCCROSSModel: Setting `max_epochs` = 1056
# [INFO] SCCROSSModel: Setting `patience` = 88
# [INFO] SCCROSSModel: Setting `reduce_lr_patience` = 44
# [INFO] SCCROSSTrainer: Using training directory: "sccross/pretrain"
#  UserWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/torch/optim/lr_scheduler.py:60: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
# [INFO] SCCROSSTrainer: [Epoch 10] train={'x_rna_nll': 0.286, 'x_rna_kl': 0.027, 'x_rna_elbo': 0.313, 'x_atac_nll': 0.38, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.381, 'dsc_loss': 0.0, 'vae_loss': 0.72, 'gen_loss': 0.72}, val={'x_rna_nll': 0.298, 'x_rna_kl': 0.026, 'x_rna_elbo': 0.324, 'x_atac_nll': 0.403, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.404, 'dsc_loss': 0.699, 'vae_loss': 3.569, 'gen_loss': -296.884}, 1.8s elapsed
# [INFO] SCCROSSTrainer: [Epoch 20] train={'x_rna_nll': 0.279, 'x_rna_kl': 0.018, 'x_rna_elbo': 0.297, 'x_atac_nll': 0.375, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.376, 'dsc_loss': 0.0, 'vae_loss': 0.684, 'gen_loss': 0.684}, val={'x_rna_nll': 0.276, 'x_rna_kl': 0.016, 'x_rna_elbo': 0.292, 'x_atac_nll': 0.387, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.388, 'dsc_loss': 0.698, 'vae_loss': 3.389, 'gen_loss': -296.926}, 1.8s elapsed
# [INFO] SCCROSSTrainer: [Epoch 30] train={'x_rna_nll': 0.274, 'x_rna_kl': 0.011, 'x_rna_elbo': 0.285, 'x_atac_nll': 0.368, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.369, 'dsc_loss': 0.0, 'vae_loss': 0.66, 'gen_loss': 0.66}, val={'x_rna_nll': 0.291, 'x_rna_kl': 0.011, 'x_rna_elbo': 0.301, 'x_atac_nll': 0.388, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.389, 'dsc_loss': 0.699, 'vae_loss': 3.434, 'gen_loss': -298.315}, 1.8s elapsed
# [INFO] SCCROSSTrainer: [Epoch 40] train={'x_rna_nll': 0.272, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.281, 'x_atac_nll': 0.369, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.37, 'dsc_loss': 0.0, 'vae_loss': 0.654, 'gen_loss': 0.654}, val={'x_rna_nll': 0.267, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.275, 'x_atac_nll': 0.402, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.403, 'dsc_loss': 0.697, 'vae_loss': 3.364, 'gen_loss': -299.144}, 1.8s elapsed
# [INFO] SCCROSSTrainer: [Epoch 50] train={'x_rna_nll': 0.27, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.277, 'x_atac_nll': 0.364, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.365, 'dsc_loss': 0.0, 'vae_loss': 0.645, 'gen_loss': 0.645}, val={'x_rna_nll': 0.281, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.289, 'x_atac_nll': 0.393, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.395, 'dsc_loss': 0.697, 'vae_loss': 3.32, 'gen_loss': -298.64}, 1.8s elapsed
# [INFO] SCCROSSTrainer: [Epoch 60] train={'x_rna_nll': 0.271, 'x_rna_kl': 0.007, 'x_rna_elbo': 0.278, 'x_atac_nll': 0.368, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.37, 'dsc_loss': 0.0, 'vae_loss': 0.651, 'gen_loss': 0.651}, val={'x_rna_nll': 0.269, 'x_rna_kl': 0.007, 'x_rna_elbo': 0.276, 'x_atac_nll': 0.376, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.377, 'dsc_loss': 0.697, 'vae_loss': 3.228, 'gen_loss': -297.975}, 1.8s elapsed
# [INFO] SCCROSSTrainer: [Epoch 70] train={'x_rna_nll': 0.27, 'x_rna_kl': 0.007, 'x_rna_elbo': 0.277, 'x_atac_nll': 0.364, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.366, 'dsc_loss': 0.0, 'vae_loss': 0.645, 'gen_loss': 0.645}, val={'x_rna_nll': 0.276, 'x_rna_kl': 0.007, 'x_rna_elbo': 0.283, 'x_atac_nll': 0.374, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.375, 'dsc_loss': 0.697, 'vae_loss': 3.22, 'gen_loss': -298.467}, 1.8s elapsed
# [INFO] SCCROSSTrainer: [Epoch 80] train={'x_rna_nll': 0.268, 'x_rna_kl': 0.007, 'x_rna_elbo': 0.275, 'x_atac_nll': 0.361, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.362, 'dsc_loss': 0.0, 'vae_loss': 0.64, 'gen_loss': 0.64}, val={'x_rna_nll': 0.278, 'x_rna_kl': 0.006, 'x_rna_elbo': 0.284, 'x_atac_nll': 0.373, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.375, 'dsc_loss': 0.697, 'vae_loss': 3.173, 'gen_loss': -298.794}, 1.8s elapsed
# [INFO] SCCROSSTrainer: [Epoch 90] train={'x_rna_nll': 0.266, 'x_rna_kl': 0.006, 'x_rna_elbo': 0.272, 'x_atac_nll': 0.36, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.361, 'dsc_loss': 0.0, 'vae_loss': 0.636, 'gen_loss': 0.636}, val={'x_rna_nll': 0.28, 'x_rna_kl': 0.006, 'x_rna_elbo': 0.286, 'x_atac_nll': 0.38, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.381, 'dsc_loss': 0.697, 'vae_loss': 3.208, 'gen_loss': -296.213}, 1.8s elapsed
# [INFO] SCCROSSTrainer: [Epoch 100] train={'x_rna_nll': 0.266, 'x_rna_kl': 0.006, 'x_rna_elbo': 0.273, 'x_atac_nll': 0.366, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.367, 'dsc_loss': 0.0, 'vae_loss': 0.642, 'gen_loss': 0.642}, val={'x_rna_nll': 0.266, 'x_rna_kl': 0.006, 'x_rna_elbo': 0.272, 'x_atac_nll': 0.373, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.374, 'dsc_loss': 0.697, 'vae_loss': 3.239, 'gen_loss': -293.621}, 1.8s elapsed
# [INFO] SCCROSSTrainer: [Epoch 110] train={'x_rna_nll': 0.267, 'x_rna_kl': 0.006, 'x_rna_elbo': 0.273, 'x_atac_nll': 0.36, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.361, 'dsc_loss': 0.0, 'vae_loss': 0.636, 'gen_loss': 0.636}, val={'x_rna_nll': 0.276, 'x_rna_kl': 0.006, 'x_rna_elbo': 0.283, 'x_atac_nll': 0.379, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.38, 'dsc_loss': 0.696, 'vae_loss': 3.303, 'gen_loss': -295.113}, 1.8s elapsed
# [INFO] SCCROSSTrainer: [Epoch 120] train={'x_rna_nll': 0.27, 'x_rna_kl': 0.006, 'x_rna_elbo': 0.275, 'x_atac_nll': 0.361, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.363, 'dsc_loss': 0.0, 'vae_loss': 0.64, 'gen_loss': 0.64}, val={'x_rna_nll': 0.268, 'x_rna_kl': 0.006, 'x_rna_elbo': 0.274, 'x_atac_nll': 0.382, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.383, 'dsc_loss': 0.697, 'vae_loss': 3.359, 'gen_loss': -294.799}, 1.8s elapsed
# [INFO] SCCROSSTrainer: [Epoch 130] train={'x_rna_nll': 0.262, 'x_rna_kl': 0.006, 'x_rna_elbo': 0.268, 'x_atac_nll': 0.359, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.361, 'dsc_loss': 0.0, 'vae_loss': 0.631, 'gen_loss': 0.631}, val={'x_rna_nll': 0.27, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.276, 'x_atac_nll': 0.386, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.387, 'dsc_loss': 0.696, 'vae_loss': 3.447, 'gen_loss': -292.175}, 1.8s elapsed
# [INFO] SCCROSSTrainer: [Epoch 140] train={'x_rna_nll': 0.267, 'x_rna_kl': 0.006, 'x_rna_elbo': 0.273, 'x_atac_nll': 0.359, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.361, 'dsc_loss': 0.0, 'vae_loss': 0.636, 'gen_loss': 0.636}, val={'x_rna_nll': 0.26, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.265, 'x_atac_nll': 0.396, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.398, 'dsc_loss': 0.696, 'vae_loss': 3.652, 'gen_loss': -296.357}, 1.8s elapsed
# [INFO] LRScheduler: Learning rate reduction: step 1
# [INFO] SCCROSSTrainer: [Epoch 150] train={'x_rna_nll': 0.267, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.273, 'x_atac_nll': 0.358, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.359, 'dsc_loss': 0.0, 'vae_loss': 0.634, 'gen_loss': 0.634}, val={'x_rna_nll': 0.264, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.269, 'x_atac_nll': 0.385, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.386, 'dsc_loss': 0.697, 'vae_loss': 3.59, 'gen_loss': -293.716}, 1.8s elapsed
# [INFO] SCCROSSTrainer: [Epoch 160] train={'x_rna_nll': 0.267, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.273, 'x_atac_nll': 0.358, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.36, 'dsc_loss': 0.0, 'vae_loss': 0.635, 'gen_loss': 0.635}, val={'x_rna_nll': 0.263, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.268, 'x_atac_nll': 0.412, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.414, 'dsc_loss': 0.697, 'vae_loss': 3.822, 'gen_loss': -295.969}, 1.8s elapsed
# [INFO] SCCROSSTrainer: [Epoch 170] train={'x_rna_nll': 0.264, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.269, 'x_atac_nll': 0.362, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.363, 'dsc_loss': 0.0, 'vae_loss': 0.635, 'gen_loss': 0.635}, val={'x_rna_nll': 0.276, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.281, 'x_atac_nll': 0.381, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.382, 'dsc_loss': 0.696, 'vae_loss': 3.692, 'gen_loss': -295.889}, 1.7s elapsed
# [INFO] SCCROSSTrainer: [Epoch 180] train={'x_rna_nll': 0.267, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.272, 'x_atac_nll': 0.36, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.362, 'dsc_loss': 0.0, 'vae_loss': 0.636, 'gen_loss': 0.636}, val={'x_rna_nll': 0.284, 'x_rna_kl': 0.006, 'x_rna_elbo': 0.29, 'x_atac_nll': 0.379, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.381, 'dsc_loss': 0.698, 'vae_loss': 3.82, 'gen_loss': -294.879}, 1.8s elapsed
# [INFO] LRScheduler: Learning rate reduction: step 2
# [INFO] SCCROSSTrainer: [Epoch 190] train={'x_rna_nll': 0.268, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.274, 'x_atac_nll': 0.358, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.359, 'dsc_loss': 0.0, 'vae_loss': 0.635, 'gen_loss': 0.635}, val={'x_rna_nll': 0.272, 'x_rna_kl': 0.006, 'x_rna_elbo': 0.277, 'x_atac_nll': 0.365, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.366, 'dsc_loss': 0.697, 'vae_loss': 3.649, 'gen_loss': -289.255}, 1.7s elapsed
# [INFO] SCCROSSTrainer: [Epoch 200] train={'x_rna_nll': 0.267, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.272, 'x_atac_nll': 0.36, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.361, 'dsc_loss': 0.0, 'vae_loss': 0.636, 'gen_loss': 0.636}, val={'x_rna_nll': 0.279, 'x_rna_kl': 0.006, 'x_rna_elbo': 0.285, 'x_atac_nll': 0.389, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.39, 'dsc_loss': 0.697, 'vae_loss': 3.855, 'gen_loss': -295.858}, 1.7s elapsed
# [INFO] SCCROSSTrainer: [Epoch 210] train={'x_rna_nll': 0.266, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.271, 'x_atac_nll': 0.361, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.362, 'dsc_loss': 0.0, 'vae_loss': 0.636, 'gen_loss': 0.636}, val={'x_rna_nll': 0.267, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.272, 'x_atac_nll': 0.392, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.394, 'dsc_loss': 0.697, 'vae_loss': 3.808, 'gen_loss': -299.472}, 1.7s elapsed
# [INFO] SCCROSSTrainer: [Epoch 220] train={'x_rna_nll': 0.265, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.27, 'x_atac_nll': 0.359, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.36, 'dsc_loss': 0.0, 'vae_loss': 0.633, 'gen_loss': 0.633}, val={'x_rna_nll': 0.254, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.259, 'x_atac_nll': 0.405, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.406, 'dsc_loss': 0.697, 'vae_loss': 3.815, 'gen_loss': -301.395}, 1.7s elapsed
# [INFO] SCCROSSTrainer: [Epoch 230] train={'x_rna_nll': 0.267, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.272, 'x_atac_nll': 0.358, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.36, 'dsc_loss': 0.0, 'vae_loss': 0.634, 'gen_loss': 0.634}, val={'x_rna_nll': 0.266, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.271, 'x_atac_nll': 0.38, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.381, 'dsc_loss': 0.696, 'vae_loss': 3.684, 'gen_loss': -292.332}, 1.7s elapsed
# [INFO] LRScheduler: Learning rate reduction: step 3
# [INFO] SCCROSSTrainer: [Epoch 240] train={'x_rna_nll': 0.265, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.27, 'x_atac_nll': 0.358, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.36, 'dsc_loss': 0.0, 'vae_loss': 0.632, 'gen_loss': 0.632}, val={'x_rna_nll': 0.275, 'x_rna_kl': 0.006, 'x_rna_elbo': 0.281, 'x_atac_nll': 0.405, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.406, 'dsc_loss': 0.697, 'vae_loss': 3.879, 'gen_loss': -291.276}, 1.7s elapsed
# 2025-10-28 16:28:37,876 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# [INFO] EarlyStopping: Restoring checkpoint "179"...
# [INFO] EarlyStopping: Restoring checkpoint "179"...
#  FutureWarning:/home/chengyue/scCross-main/sccross/models/utils.py:649: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# [INFO] fit_SCCROSS: Fine-tuning SCCROSS model...
# [INFO] SCCROSSModel: Setting `align_burnin` = 176
# [INFO] SCCROSSModel: Setting `max_epochs` = 1056
# [INFO] SCCROSSModel: Setting `patience` = 88
# [INFO] SCCROSSModel: Setting `reduce_lr_patience` = 44
# [INFO] SCCROSSTrainer: Using training directory: "sccross/fine-tune"
#  UserWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/torch/optim/lr_scheduler.py:60: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
# [INFO] SCCROSSTrainer: [Epoch 10] train={'x_rna_nll': 0.268, 'x_rna_kl': 0.007, 'x_rna_elbo': 0.275, 'x_atac_nll': 0.359, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.36, 'dsc_loss': 0.247, 'vae_loss': 1.277, 'gen_loss': -170.073}, val={'x_rna_nll': 0.284, 'x_rna_kl': 0.007, 'x_rna_elbo': 0.291, 'x_atac_nll': 0.394, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.395, 'dsc_loss': 0.247, 'vae_loss': 1.375, 'gen_loss': -265.296}, 5.5s elapsed
# [INFO] SCCROSSTrainer: [Epoch 20] train={'x_rna_nll': 0.269, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.275, 'x_atac_nll': 0.361, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.363, 'dsc_loss': 0.404, 'vae_loss': 1.277, 'gen_loss': -233.827}, val={'x_rna_nll': 0.269, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.274, 'x_atac_nll': 0.383, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.385, 'dsc_loss': 0.423, 'vae_loss': 1.315, 'gen_loss': -299.557}, 5.4s elapsed
# [INFO] SCCROSSTrainer: [Epoch 30] train={'x_rna_nll': 0.267, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.272, 'x_atac_nll': 0.357, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.358, 'dsc_loss': 0.602, 'vae_loss': 1.261, 'gen_loss': -108.081}, val={'x_rna_nll': 0.284, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.289, 'x_atac_nll': 0.387, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.388, 'dsc_loss': 0.6, 'vae_loss': 1.351, 'gen_loss': -659.401}, 5.4s elapsed
# [INFO] SCCROSSTrainer: [Epoch 40] train={'x_rna_nll': 0.266, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.271, 'x_atac_nll': 0.359, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.361, 'dsc_loss': 0.658, 'vae_loss': 1.261, 'gen_loss': -52.697}, val={'x_rna_nll': 0.263, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.268, 'x_atac_nll': 0.403, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.404, 'dsc_loss': 0.67, 'vae_loss': 1.339, 'gen_loss': -494.291}, 5.4s elapsed
# [INFO] SCCROSSTrainer: [Epoch 50] train={'x_rna_nll': 0.265, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.27, 'x_atac_nll': 0.355, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.356, 'dsc_loss': 0.661, 'vae_loss': 1.249, 'gen_loss': -614.973}, val={'x_rna_nll': 0.277, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.281, 'x_atac_nll': 0.395, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.396, 'dsc_loss': 0.676, 'vae_loss': 1.349, 'gen_loss': -674.488}, 5.5s elapsed
# [INFO] SCCROSSTrainer: [Epoch 60] train={'x_rna_nll': 0.267, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.272, 'x_atac_nll': 0.36, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.362, 'dsc_loss': 0.668, 'vae_loss': 1.263, 'gen_loss': -75.945}, val={'x_rna_nll': 0.267, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.271, 'x_atac_nll': 0.378, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.379, 'dsc_loss': 0.673, 'vae_loss': 1.295, 'gen_loss': -788.978}, 5.4s elapsed
# [INFO] SCCROSSTrainer: [Epoch 70] train={'x_rna_nll': 0.268, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.272, 'x_atac_nll': 0.357, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.358, 'dsc_loss': 0.663, 'vae_loss': 1.255, 'gen_loss': -534.208}, val={'x_rna_nll': 0.274, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.279, 'x_atac_nll': 0.377, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.378, 'dsc_loss': 0.665, 'vae_loss': 1.306, 'gen_loss': -1424.441}, 5.4s elapsed
# [INFO] SCCROSSTrainer: [Epoch 80] train={'x_rna_nll': 0.266, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.27, 'x_atac_nll': 0.354, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.355, 'dsc_loss': 0.665, 'vae_loss': 1.246, 'gen_loss': -107.823}, val={'x_rna_nll': 0.276, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.281, 'x_atac_nll': 0.377, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.378, 'dsc_loss': 0.671, 'vae_loss': 1.31, 'gen_loss': -887.242}, 5.4s elapsed
# [INFO] SCCROSSTrainer: [Epoch 90] train={'x_rna_nll': 0.264, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.269, 'x_atac_nll': 0.353, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.354, 'dsc_loss': 0.663, 'vae_loss': 1.24, 'gen_loss': -167.698}, val={'x_rna_nll': 0.278, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.283, 'x_atac_nll': 0.383, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.385, 'dsc_loss': 0.668, 'vae_loss': 1.327, 'gen_loss': -919.715}, 5.4s elapsed
# [INFO] SCCROSSTrainer: [Epoch 100] train={'x_rna_nll': 0.265, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.269, 'x_atac_nll': 0.359, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.36, 'dsc_loss': 0.663, 'vae_loss': 1.254, 'gen_loss': -621.081}, val={'x_rna_nll': 0.266, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.27, 'x_atac_nll': 0.377, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.378, 'dsc_loss': 0.671, 'vae_loss': 1.289, 'gen_loss': -2775.916}, 5.4s elapsed
# [INFO] SCCROSSTrainer: [Epoch 110] train={'x_rna_nll': 0.266, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.27, 'x_atac_nll': 0.354, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.355, 'dsc_loss': 0.663, 'vae_loss': 1.244, 'gen_loss': -25.228}, val={'x_rna_nll': 0.276, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.281, 'x_atac_nll': 0.383, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.384, 'dsc_loss': 0.663, 'vae_loss': 1.322, 'gen_loss': -922.31}, 5.4s elapsed
# [INFO] SCCROSSTrainer: [Epoch 120] train={'x_rna_nll': 0.268, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.273, 'x_atac_nll': 0.356, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.357, 'dsc_loss': 0.656, 'vae_loss': 1.253, 'gen_loss': -15.357}, val={'x_rna_nll': 0.268, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.272, 'x_atac_nll': 0.386, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.387, 'dsc_loss': 0.658, 'vae_loss': 1.312, 'gen_loss': -1154.321}, 5.1s elapsed
# [INFO] SCCROSSTrainer: [Epoch 130] train={'x_rna_nll': 0.262, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.266, 'x_atac_nll': 0.354, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.355, 'dsc_loss': 0.656, 'vae_loss': 1.236, 'gen_loss': -12.381}, val={'x_rna_nll': 0.27, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.274, 'x_atac_nll': 0.39, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.391, 'dsc_loss': 0.666, 'vae_loss': 1.325, 'gen_loss': -1340.691}, 5.5s elapsed
# [INFO] SCCROSSTrainer: [Epoch 140] train={'x_rna_nll': 0.267, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.271, 'x_atac_nll': 0.354, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.356, 'dsc_loss': 0.654, 'vae_loss': 1.247, 'gen_loss': -14.972}, val={'x_rna_nll': 0.26, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.265, 'x_atac_nll': 0.401, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.402, 'dsc_loss': 0.667, 'vae_loss': 1.325, 'gen_loss': -1425.149}, 5.5s elapsed
# [INFO] SCCROSSTrainer: [Epoch 150] train={'x_rna_nll': 0.267, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.271, 'x_atac_nll': 0.353, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.355, 'dsc_loss': 0.65, 'vae_loss': 1.246, 'gen_loss': -119.346}, val={'x_rna_nll': 0.264, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.268, 'x_atac_nll': 0.389, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.391, 'dsc_loss': 0.688, 'vae_loss': 1.311, 'gen_loss': -1113.745}, 5.4s elapsed
# [INFO] SCCROSSTrainer: [Epoch 160] train={'x_rna_nll': 0.267, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.272, 'x_atac_nll': 0.354, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.355, 'dsc_loss': 0.649, 'vae_loss': 1.247, 'gen_loss': -258.697}, val={'x_rna_nll': 0.264, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.268, 'x_atac_nll': 0.417, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.418, 'dsc_loss': 0.658, 'vae_loss': 1.365, 'gen_loss': -1330.131}, 5.4s elapsed
# [INFO] SCCROSSTrainer: [Epoch 170] train={'x_rna_nll': 0.264, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.268, 'x_atac_nll': 0.357, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.358, 'dsc_loss': 0.644, 'vae_loss': 1.246, 'gen_loss': -106.776}, val={'x_rna_nll': 0.277, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.281, 'x_atac_nll': 0.385, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.386, 'dsc_loss': 0.642, 'vae_loss': 1.327, 'gen_loss': -1080.249}, 5.5s elapsed
# [INFO] SCCROSSTrainer: [Epoch 180] train={'x_rna_nll': 0.266, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.271, 'x_atac_nll': 0.356, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.357, 'dsc_loss': 0.648, 'vae_loss': 1.249, 'gen_loss': -101.588}, val={'x_rna_nll': 0.284, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.289, 'x_atac_nll': 0.384, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.385, 'dsc_loss': 0.649, 'vae_loss': 1.34, 'gen_loss': -1098.01}, 5.3s elapsed
# [INFO] SCCROSSTrainer: [Epoch 190] train={'x_rna_nll': 0.268, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.272, 'x_atac_nll': 0.353, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.354, 'dsc_loss': 0.651, 'vae_loss': 1.247, 'gen_loss': -12.266}, val={'x_rna_nll': 0.272, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.277, 'x_atac_nll': 0.369, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.37, 'dsc_loss': 0.661, 'vae_loss': 1.287, 'gen_loss': -1138.866}, 5.4s elapsed
# [INFO] SCCROSSTrainer: [Epoch 200] train={'x_rna_nll': 0.267, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.271, 'x_atac_nll': 0.355, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.356, 'dsc_loss': 0.649, 'vae_loss': 1.248, 'gen_loss': -14.051}, val={'x_rna_nll': 0.279, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.284, 'x_atac_nll': 0.394, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.395, 'dsc_loss': 0.661, 'vae_loss': 1.35, 'gen_loss': -1722.331}, 5.4s elapsed
# [INFO] SCCROSSTrainer: [Epoch 210] train={'x_rna_nll': 0.266, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.27, 'x_atac_nll': 0.356, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.357, 'dsc_loss': 0.648, 'vae_loss': 1.248, 'gen_loss': -7.845}, val={'x_rna_nll': 0.267, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.271, 'x_atac_nll': 0.397, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.398, 'dsc_loss': 0.658, 'vae_loss': 1.332, 'gen_loss': -1816.861}, 5.3s elapsed
# [INFO] SCCROSSTrainer: [Epoch 220] train={'x_rna_nll': 0.265, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.269, 'x_atac_nll': 0.354, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.355, 'dsc_loss': 0.645, 'vae_loss': 1.241, 'gen_loss': -10.59}, val={'x_rna_nll': 0.254, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.258, 'x_atac_nll': 0.41, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.411, 'dsc_loss': 0.653, 'vae_loss': 1.332, 'gen_loss': -1625.327}, 5.3s elapsed
# [INFO] LRScheduler: Learning rate reduction: step 1
# [INFO] SCCROSSTrainer: [Epoch 230] train={'x_rna_nll': 0.266, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.271, 'x_atac_nll': 0.353, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.354, 'dsc_loss': 0.673, 'vae_loss': 1.242, 'gen_loss': -5.404}, val={'x_rna_nll': 0.266, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.27, 'x_atac_nll': 0.385, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.386, 'dsc_loss': 0.651, 'vae_loss': 1.306, 'gen_loss': -2115.837}, 5.4s elapsed
# [INFO] SCCROSSTrainer: [Epoch 240] train={'x_rna_nll': 0.264, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.269, 'x_atac_nll': 0.353, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.354, 'dsc_loss': 0.663, 'vae_loss': 1.239, 'gen_loss': -3.233}, val={'x_rna_nll': 0.275, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.28, 'x_atac_nll': 0.41, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.411, 'dsc_loss': 0.642, 'vae_loss': 1.374, 'gen_loss': -2527.593}, 5.4s elapsed
# [INFO] SCCROSSTrainer: [Epoch 250] train={'x_rna_nll': 0.266, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.27, 'x_atac_nll': 0.354, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.355, 'dsc_loss': 0.668, 'vae_loss': 1.244, 'gen_loss': -3.48}, val={'x_rna_nll': 0.273, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.277, 'x_atac_nll': 0.392, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.393, 'dsc_loss': 0.64, 'vae_loss': 1.334, 'gen_loss': -2939.842}, 5.3s elapsed
# [INFO] SCCROSSTrainer: [Epoch 260] train={'x_rna_nll': 0.265, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.269, 'x_atac_nll': 0.356, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.358, 'dsc_loss': 0.667, 'vae_loss': 1.247, 'gen_loss': -1.924}, val={'x_rna_nll': 0.268, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.273, 'x_atac_nll': 0.395, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.396, 'dsc_loss': 0.646, 'vae_loss': 1.33, 'gen_loss': -3034.329}, 5.3s elapsed
# [INFO] LRScheduler: Learning rate reduction: step 2
# [INFO] SCCROSSTrainer: [Epoch 270] train={'x_rna_nll': 0.264, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.268, 'x_atac_nll': 0.353, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.354, 'dsc_loss': 0.666, 'vae_loss': 1.238, 'gen_loss': -1.96}, val={'x_rna_nll': 0.269, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.274, 'x_atac_nll': 0.387, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.388, 'dsc_loss': 0.655, 'vae_loss': 1.316, 'gen_loss': -3211.992}, 5.4s elapsed
# [INFO] SCCROSSTrainer: [Epoch 280] train={'x_rna_nll': 0.268, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.273, 'x_atac_nll': 0.35, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.351, 'dsc_loss': 0.663, 'vae_loss': 1.241, 'gen_loss': -2.886}, val={'x_rna_nll': 0.263, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.267, 'x_atac_nll': 0.39, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.391, 'dsc_loss': 0.645, 'vae_loss': 1.31, 'gen_loss': -3292.579}, 5.3s elapsed
# [INFO] SCCROSSTrainer: [Epoch 290] train={'x_rna_nll': 0.263, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.267, 'x_atac_nll': 0.352, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.353, 'dsc_loss': 0.664, 'vae_loss': 1.233, 'gen_loss': -0.952}, val={'x_rna_nll': 0.273, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.278, 'x_atac_nll': 0.393, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.394, 'dsc_loss': 0.641, 'vae_loss': 1.336, 'gen_loss': -3460.136}, 5.3s elapsed
# [INFO] SCCROSSTrainer: [Epoch 300] train={'x_rna_nll': 0.263, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.268, 'x_atac_nll': 0.354, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.355, 'dsc_loss': 0.661, 'vae_loss': 1.239, 'gen_loss': -1.784}, val={'x_rna_nll': 0.272, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.276, 'x_atac_nll': 0.384, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.386, 'dsc_loss': 0.648, 'vae_loss': 1.316, 'gen_loss': -3313.654}, 5.3s elapsed
# [INFO] SCCROSSTrainer: [Epoch 310] train={'x_rna_nll': 0.262, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.267, 'x_atac_nll': 0.352, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.353, 'dsc_loss': 0.664, 'vae_loss': 1.232, 'gen_loss': -1.549}, val={'x_rna_nll': 0.272, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.277, 'x_atac_nll': 0.385, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.386, 'dsc_loss': 0.635, 'vae_loss': 1.318, 'gen_loss': -3528.409}, 5.4s elapsed
# [INFO] LRScheduler: Learning rate reduction: step 3
# [INFO] SCCROSSTrainer: [Epoch 320] train={'x_rna_nll': 0.265, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.269, 'x_atac_nll': 0.35, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.352, 'dsc_loss': 0.663, 'vae_loss': 1.234, 'gen_loss': -1.821}, val={'x_rna_nll': 0.27, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.275, 'x_atac_nll': 0.402, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.403, 'dsc_loss': 0.634, 'vae_loss': 1.348, 'gen_loss': -3346.805}, 5.2s elapsed
# [INFO] SCCROSSTrainer: [Epoch 330] train={'x_rna_nll': 0.263, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.267, 'x_atac_nll': 0.357, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.358, 'dsc_loss': 0.662, 'vae_loss': 1.243, 'gen_loss': -1.173}, val={'x_rna_nll': 0.274, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.278, 'x_atac_nll': 0.372, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.374, 'dsc_loss': 0.64, 'vae_loss': 1.296, 'gen_loss': -3464.886}, 5.2s elapsed
# [INFO] SCCROSSTrainer: [Epoch 340] train={'x_rna_nll': 0.264, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.268, 'x_atac_nll': 0.357, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.358, 'dsc_loss': 0.664, 'vae_loss': 1.244, 'gen_loss': -1.119}, val={'x_rna_nll': 0.264, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.268, 'x_atac_nll': 0.384, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.385, 'dsc_loss': 0.643, 'vae_loss': 1.299, 'gen_loss': -3421.11}, 5.2s elapsed
# [INFO] SCCROSSTrainer: [Epoch 350] train={'x_rna_nll': 0.266, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.271, 'x_atac_nll': 0.352, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.354, 'dsc_loss': 0.662, 'vae_loss': 1.241, 'gen_loss': -1.989}, val={'x_rna_nll': 0.262, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.267, 'x_atac_nll': 0.398, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.4, 'dsc_loss': 0.64, 'vae_loss': 1.325, 'gen_loss': -3405.671}, 5.3s elapsed
# [INFO] LRScheduler: Learning rate reduction: step 4
# [INFO] SCCROSSTrainer: [Epoch 360] train={'x_rna_nll': 0.265, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.269, 'x_atac_nll': 0.353, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.355, 'dsc_loss': 0.665, 'vae_loss': 1.24, 'gen_loss': -1.591}, val={'x_rna_nll': 0.272, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.276, 'x_atac_nll': 0.398, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.4, 'dsc_loss': 0.644, 'vae_loss': 1.344, 'gen_loss': -3369.444}, 5.3s elapsed
# [INFO] SCCROSSTrainer: [Epoch 370] train={'x_rna_nll': 0.265, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.27, 'x_atac_nll': 0.349, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.351, 'dsc_loss': 0.665, 'vae_loss': 1.233, 'gen_loss': -1.114}, val={'x_rna_nll': 0.268, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.272, 'x_atac_nll': 0.389, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.39, 'dsc_loss': 0.64, 'vae_loss': 1.317, 'gen_loss': -3501.879}, 5.4s elapsed
# [INFO] SCCROSSTrainer: [Epoch 380] train={'x_rna_nll': 0.263, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.268, 'x_atac_nll': 0.351, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.353, 'dsc_loss': 0.668, 'vae_loss': 1.234, 'gen_loss': -1.291}, val={'x_rna_nll': 0.26, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.265, 'x_atac_nll': 0.378, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.379, 'dsc_loss': 0.643, 'vae_loss': 1.279, 'gen_loss': -3497.367}, 5.0s elapsed
# [INFO] SCCROSSTrainer: [Epoch 390] train={'x_rna_nll': 0.263, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.268, 'x_atac_nll': 0.361, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.362, 'dsc_loss': 0.667, 'vae_loss': 1.252, 'gen_loss': -2.076}, val={'x_rna_nll': 0.268, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.272, 'x_atac_nll': 0.383, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.385, 'dsc_loss': 0.64, 'vae_loss': 1.306, 'gen_loss': -3455.002}, 5.0s elapsed
# [INFO] SCCROSSTrainer: [Epoch 400] train={'x_rna_nll': 0.264, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.268, 'x_atac_nll': 0.351, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.352, 'dsc_loss': 0.667, 'vae_loss': 1.233, 'gen_loss': -2.072}, val={'x_rna_nll': 0.283, 'x_rna_kl': 0.005, 'x_rna_elbo': 0.288, 'x_atac_nll': 0.378, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.379, 'dsc_loss': 0.636, 'vae_loss': 1.326, 'gen_loss': -3434.304}, 5.2s elapsed
# [INFO] LRScheduler: Learning rate reduction: step 5
# [INFO] SCCROSSTrainer: [Epoch 410] train={'x_rna_nll': 0.263, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.268, 'x_atac_nll': 0.356, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.357, 'dsc_loss': 0.664, 'vae_loss': 1.243, 'gen_loss': -1.571}, val={'x_rna_nll': 0.27, 'x_rna_kl': 0.004, 'x_rna_elbo': 0.274, 'x_atac_nll': 0.396, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.397, 'dsc_loss': 0.645, 'vae_loss': 1.335, 'gen_loss': -3477.737}, 5.3s elapsed
# 2025-10-28 17:08:32,805 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# [INFO] EarlyStopping: Restoring checkpoint "384"...
#  FutureWarning:/home/chengyue/scCross-main/sccross/models/utils.py:649: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# [INFO] EarlyStopping: Restoring checkpoint "384"...
#  ImplicitModificationWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/anndata/_core/anndata.py:121: Transforming to str index.
#  UserWarning:/data1/chengyue/miniconda3/envs/sccross/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.

# %%
cell_name = pd.read_csv('/data1/chengyue/gm/fig2/human_brain_3k/label.csv', usecols=[1])
cell_type, y = np.unique(cell_name, return_inverse=True)
n_clusters = int(max(y) - min(y) + 1)  
kmeans = KMeans(n_clusters = n_clusters, n_init=20)
latent_atac = atac.obsm["X_cross"]
y_pred_z = kmeans.fit_predict(latent_atac)   
nmi, ari, ami, fmi, hom, com, v = eva(y, y_pred_z)
db, ch, asw = eva_nolabel(latent_atac, y_pred_z)
print('ATAC: nmi, ari, ami, fmi, hom, com, v:', nmi, ari, ami, fmi, hom, com, v)
print('ATAC: db, ch, asw:', db, ch, asw)
# Out:
# ATAC: nmi, ari, ami, fmi, hom, com, v: 0.47796953486984095 0.24613578179880016 0.47475403070272826 0.3608016159307791 0.4501751366442434 0.509421905642271 0.47796953486984106
# ATAC: db, ch, asw: 1.946052007018269 265.6202739248042 0.15280178
